# %%
import zipfile
import pandas as pd
import sqlite3

caminho_ate_zip = r"C:\Users\SGP 3\Desktop\projeto\data_analytics_jr_test\Data\Data.zip"
arquivo_desejado = "Data/Escolas/escolas122018.csv"

with zipfile.ZipFile(caminho_ate_zip,'r') as zip_ref:
    with zip_ref.open(arquivo_desejado) as arquivo:
        df = pd.read_csv(arquivo, encoding='latin1', sep=';')
df.columns
# Out:
# Index(['ï»¿dre', 'codesc', 'tipoesc', 'nomesc', 'ceu', 'diretoria', 'subpref',
#        'endereco', 'numero', 'bairro', 'cep', 'tel1', 'tel2', 'fax',
#        'situacao', 'coddist', 'distrito', 'setor', 'codinep', 'cd_cie', 'eh',
#        'fx_etaria', 'dt_criacao', 'ato_criacao', 'doc_criacao', 'dt_ini_conv',
#        'dt_ini_func', 'dt_autoriza', 'dt_extintao', 'nome_ant', 'rede',
#        'latitude', 'longitude', 'database'],
#       dtype='object')

# %%
#Cria uma lista com os arquivos dentro da pasta zip e que não estão na pasta macosx
lista_arquivos = []
pasta_arquivos = "Data/Data/Escolas/"
with zipfile.ZipFile(caminho_ate_zip,'r') as zip_ref:
    # with zip_ref.open(pasta_escolas) as arquivo:
    #     print(zip_ref.namelist())
    lista_arquivos = [f for f in zip_ref.namelist() if f.endswith(".csv") and not f.startswith("__MACOSX")]
print("Quantidade de arquivos: {}".format(len(lista_arquivos)))
# Out:
# Quantidade de arquivos: 22

# %%
#salva o nome dos arquivos na lista correta
arquivos_escolas = []
arquivos_alunos = []
for item in lista_arquivos:
    indice = item.find("/",6)
    nome = item[indice +1:]
    if 'escolas' in nome:
        arquivos_escolas.append(nome)
    elif 'idadeserieneeraca' in nome:
        arquivos_alunos.append(nome)

print("Escolas: {} arquivos, Alunos : {} arquivos, Total : {}".format(len(arquivos_escolas),len(arquivos_alunos),len(arquivos_escolas) +len(arquivos_alunos)))
# Out:
# Escolas: 14 arquivos, Alunos : 8 arquivos, Total : 22

# %%
lista_df_escolas = []
lista_df_alunos = []

import zipfile
import pandas as pd

caminho_ate_zip = r"C:\Users\SGP 3\Desktop\projeto\data_analytics_jr_test\Data\Data.zip"
arquivo_desejado = "Data/Escolas/escolas122018.csv"
for arquivo in arquivos_escolas:
    with zipfile.ZipFile(caminho_ate_zip,'r') as zip_ref:
        with zip_ref.open(arquivo_desejado) as arquivo:
            arquivo = (pd.read_csv(arquivo, encoding='latin1', sep=';'))
            lista_df_escolas.append(arquivo)
for arquivo in arquivos_alunos:
    with zipfile.ZipFile(caminho_ate_zip,'r') as zip_ref:
        with zip_ref.open(arquivo_desejado) as arquivo:
            arquivo = (pd.read_csv(arquivo, encoding='latin1', sep=';'))
            lista_df_alunos.append(arquivo)

# %%
lista_df_escolas[2]
# Out:
#      ï»¿dre  codesc       tipoesc  \
# 0        BT     191  EMEF
# 1        BT     213  EMEI
# 2        BT     477  EMEF
# 3        BT   11924  EMEF
# 4        BT   14591  EMEI
# ...     ...     ...           ...
# 4748     SM  501468  MOVA
# 4749     SM  501507  MOVA
# 4750     SM  501513  MOVA
# 4751     SM  501576  MOVA
# 4752     SM  501581  MOVA
#
#                                                  nomesc  ceu  \
# 0                              ALIPIO CORREA NETO, PROF  NaN
# 1                  ANTONIO CARLOS PACHECO E SILVA, PROF  NaN
# 2                   PROFA. EDA TEREZINHA CHICA MEDEIROS  NaN
# 3                       PROFA. MARIA ALICE BORGES GHION  NaN
# 4                             PROF. BENEDICTO CASTRUCCI  NaN
# ...                                                 ...  ...
# 4748  ASS MORADORES NA LUTA MORADIA DO CONJ TEOTONIO...  NaN
# 4749                 ASS MORAODRES NA LUTA PELA MORADIA  NaN
# 4750  ASS MORADORES NA LUTA P MORADIA DO CONJ TEOTON...  NaN
# 4751                              AEC PADRE LUIZ SUTTER  NaN
# 4752                  ASS EDUC E CULT PADRE LUIZ SUTTER  NaN
#
#                                       diretoria     subpref  \
# 0        DIRETORIA REGIONAL DE EDUCACAO BUTANTA     BUTANTA
# 1        DIRETORIA REGIONAL DE EDUCACAO BUTANTA     BUTANTA
# 2        DIRETORIA REGIONAL DE EDUCACAO BUTANTA     BUTANTA
# 3        DIRETORIA REGIONAL DE EDUCACAO BUTANTA     BUTANTA
# 4        DIRETORIA REGIONAL DE EDUCACAO BUTANTA     BUTANTA
# ...                                         ...         ...
# 4748  DIRETORIA REGIONAL DE EDUCACAO SAO MATEUS   SAPOPEMBA
# 4749  DIRETORIA REGIONAL DE EDUCACAO SAO MATEUS   SAPOPEMBA
# 4750  DIRETORIA REGIONAL DE EDUCACAO SAO MATEUS  SAO MATEUS
# 4751  DIRETORIA REGIONAL DE EDUCACAO SAO MATEUS  SAO MATEUS
# 4752  DIRETORIA REGIONAL DE EDUCACAO SAO MATEUS  SAO MATEUS
#
#                            endereco  numero  \
# 0              Avenida JOAO CAIAFFA     140
# 1           Avenida JOÃÆO CAIAFFA      90
# 2     Rua ENGENHEIRO HUGO TAKAHASHI     333
# 3          Rua CACHOEIRA PORAQUÃÅ      575
# 4             Rua CACHOEIRA PORAQUE  S/N
# ...                             ...     ...
# 4748       Travessa CECÃÂLIO BAEZ      16
# 4749           Rua ESQUIVEL NAVARRO     677
# 4750     Rua JOAQUIM GOUVEIA FRANCO     928
# 4751         Rua MARTINS LOPES LOBO      63
# 4752          Rua DAS CATILÃâ°IAS      26
#
#                                      bairro  ...  doc_criacao  dt_ini_conv  \
# 0                             JARDIM TABOAO  ...   27/05/1988          NaN
# 1                          JARDIM TABOÃÆO  ...   07/06/1988          NaN
# 2                            RAPOSO TAVARES  ...   26/10/1988          NaN
# 3          CONJUNTO PROMORAR RAPOSO TAVARES  ...   17/02/1992          NaN
# 4          CONJUNTO PROMORAR RAPOSO TAVARES  ...   02/03/1994          NaN
# ...                                     ...  ...          ...          ...
# 4748                        FAZENDA DA JUTA  ...   18/10/2013   18/10/2013
# 4749  CONJUNTO HABITACIONAL TEOTONIO VILELA  ...   11/03/2015          NaN
# 4750                   CIDADE SÃÆO MATEUS  ...   11/06/2015          NaN
# 4751                JARDIM SÃÆO FRANCISCO  ...   20/07/2016          NaN
# 4752                      PARQUE DAS FLORES  ...   16/11/2016          NaN
#
#      dt_ini_func  dt_autoriza dt_extintao  \
# 0     02/10/1988   16/03/1991         NaN
# 1     26/09/1988   13/03/2001         NaN
# 2     20/02/1989   16/03/1991         NaN
# 3     20/02/1992   13/03/2001         NaN
# 4     13/04/1994   13/03/2001         NaN
# ...          ...          ...         ...
# 4748         NaN          NaN         NaN
# 4749         NaN          NaN         NaN
# 4750         NaN          NaN         NaN
# 4751         NaN          NaN         NaN
# 4752         NaN          NaN         NaN
#
#                                                nome_ant rede     latitude  \
# 0                             ALIPIO CORREA NETO, PROF.  DIR  -23.612.237
# 1                 ANTONIO CARLOS PACHECO E SILVA, PROF.  DIR  -23.611.929
# 2                  EDA TEREZINHA CHICA MEDEIROS, PROFA.  DIR  -23.602.076
# 3                      MARIA ALICE BORGES GHION, PROFA.  DIR  -23.586.959
# 4                     CONJ. HABITACIONAL RAPOSO TAVARES  DIR  -23.586.339
# ...                                                 ...  ...          ...
# 4748  ASS MORADORES NA LUTA MORADIA DO CONJ TEOTONIO...  CON  -23.623.674
# 4749                 ASS MORADORES NA LUTA PELA MORADIA  CON  -23.607.238
# 4750  ASS MORADORES NA LUTA P MORADIA DO CONJ TEOTON...  CON  -23.596.456
# 4751                              AEC PADRE LUIZ SUTTER  CON  -23.624.554
# 4752                  ASS EDUC E CULT PADRE LUIZ SUTTER  CON  -23.604.463
#
#         longitude    database
# 0     -46.749.888  30/12/2018
# 1     -46.750.176  30/12/2018
# 2     -46.783.825  30/12/2018
# 3     -46.801.039  30/12/2018
# 4     -46.800.967  30/12/2018
# ...           ...         ...
# 4748  -46.489.887  30/12/2018
# 4749   -4.650.539  30/12/2018
# 4750  -46.490.716  30/12/2018
# 4751  -46.448.039  30/12/2018
# 4752  -46.640.239  30/12/2018
#
# [4753 rows x 34 columns]
